# %% [markdown]
# # **Domain and Range**

# %% [markdown]
# - The **domain** is the set of all valid inputs $x$ where the function is defined.
# - The **range** is the set of all possible outputs $f(x)$.
#
# ### **Common Restrictions on Domain:**
# 1. **Denominators** must not be zero.
# 2. **Even roots** (e.g. $\sqrt{x}$) require non-negative radicands.
# 3. **Logarithms** require the argument to be positive.
#
# ### **Tips to Find Range:**
# - Use function behavior or graph.
# - Solve $y = f(x)$ for $x$ if possible, to find output bounds.
# - Always **use domain restrictions** to guide your range analysis.

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 1
# - Find the Domain and Range of $Y(t)=3t^2 - 2t + 1$
#
# ### Solution
#
# **Domain**
# - We can input any real number:
# $$
# \boxed{D = (-\infty, \infty)}
# $$
#
# **Range**
# 1. The coefficient of $t^2$ is positive (3), so parabola opens upward
# 2. Find vertex using $t = -\frac{b}{2a}$:
# $$
# t = \frac{-(-2)}{2(3)} = \frac{1}{3}
# $$
# 3. Calculate $Y\left(\frac{1}{3}\right)$:
# $$
# 3\left(\frac{1}{3}\right)^2 - 2\left(\frac{1}{3}\right) + 1 = \frac{2}{3}
# $$
# 4. Since parabola has minimum at vertex:
# $$
# \boxed{R = \left[\frac{2}{3}, \infty\right)}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def Y(t):
    return 3 * t**2 - 2 * t + 1

# Generate t values
t = np.linspace(-10, 10, 400)  # Adjust the range as needed
y = Y(t)

# Find the vertex (t_v, y_v)
t_v = -(-2) / (2 * 3)  # t = -b/(2a)
y_v = Y(t_v)

# Plot the function
plt.figure(figsize=(8, 6))
plt.plot(t, y, label=r'$Y(t) = 3t^2 - 2t + 1$', color='blue')

# Mark the vertex
plt.scatter(t_v, y_v, color='red', label=f'Vertex at ({t_v:.2f}, {y_v:.2f})')

# Add domain and range annotations
plt.text(0.5, 15, f'Domain: $(-\\infty, \\infty)$\nRange: $[{y_v:.2f}, \\infty)$',
         bbox=dict(facecolor='white', alpha=0.8))

# Add labels and title
plt.xlabel('t')
plt.ylabel('Y(t)')
plt.title('Graph of $Y(t) = 3t^2 - 2t + 1$')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 2
# - Find the Domain and Range of $g(z) = -z^2 - 4z + 7$
#
# ### Solution
#
# **Domain**
# - We can input any real number:
# $$
# \boxed{D = (-\infty, \infty)}
# $$
#
# **Range**
# 1. The coefficient of $z^2$ is negative (-1), so parabola opens downward
# 2. Find vertex using $z = -\frac{b}{2a}$:
# $$
# z = -\frac{-4}{2(-1)} = -2
# $$
# 3. Calculate $g(-2)$:
# $$
# -(-2)^2 - 4(-2) + 7 = 11
# $$
# 4. Since parabola has maximum at vertex:
# $$
# \boxed{R = (-\infty, 11]}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def g(z):
    return -z**2 - 4*z + 7

# Generate z values
z = np.linspace(-10, 10, 400) 
y = g(z)

# Find the vertex (z_v, g_v)
z_v = -(-4) / (2 * -1)  # z = -b/(2a)
g_v = g(z_v)

# Plot the function
plt.figure(figsize=(8, 6))
plt.plot(z, y, label=r'$g(z) = -z^2 - 4z + 7$', color='blue')

# Mark the vertex
plt.scatter(z_v, g_v, color='red', label=f'Vertex at ({z_v:.2f}, {g_v:.2f})')

# Add domain and range annotations
plt.text(-5, -15, f'Domain: $(-\\infty, \\infty)$\nRange: $(-\\infty, {g_v:.2f}]$',
         bbox=dict(facecolor='white', alpha=0.8))

# Highlight the range (horizontal line at y = g_v)
plt.axhline(g_v, color='green', linestyle='--', alpha=0.5, label=f'Max Range: y = {g_v:.2f}')

# Add labels and title
plt.xlabel('z')
plt.ylabel('g(z)')
plt.title('Graph of $g(z) = -z^2 - 4z + 7$')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.ylim(-15, 12)  # Adjust y-axis to show key features
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 3
# - Find the Domain and Range of $f(z) = 2 + \sqrt{z^2 + 1}$
#
# ### Solution
#
# **Domain**
# 1. The expression under square root must satisfy $z^2 + 1 \geq 0$
# 2. Since $z^2 \geq 0$ for all real $z$, then $z^2 + 1 \geq 1 > 0$ always
# 3. Therefore, no restrictions on $z$:
# $$
# \boxed{D = (-\infty, \infty)}
# $$
#
# **Range**
# 1. Analyze the components:
#    - $z^2 \geq 0$ for all real $z$
#    - Therefore $z^2 + 1 \geq 1$
#    - $\sqrt{z^2 + 1} \geq 1$ (since square root is increasing)
# 2. Add 2 to both sides:
#    - $2 + \sqrt{z^2 + 1} \geq 3$
# 3. As $z^2$ grows, the function increases without bound
# 4. Therefore the range is:
# $$
# \boxed{R = [3, \infty)}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def f(z):
    return 2 + np.sqrt(z**2 + 1)

# Generate z values
z = np.linspace(-5, 5, 400)
y = f(z)

# Find minimum at z = 0
f_min = f(0)

# Plot
plt.figure(figsize=(8, 6))
plt.plot(z, y, label=r'$f(z) = 2 + \sqrt{z^2 + 1}$', color='blue')  # Raw string here too
plt.scatter(0, f_min, color='red', label=f'Minimum at (0, {f_min:.1f})')

# Annotations (raw strings)
plt.text(-4.8, 8, 
         r'Domain: $(-\infty, \infty)$' + '\n' + r'Range: $[3, \infty)$',  # Raw for LaTeX
         bbox=dict(facecolor='white', alpha=0.8))
plt.axhline(f_min, color='green', linestyle='--', alpha=0.5, label='Min Range: y = 3')

# Labels and title (raw string)
plt.xlabel('z')
plt.ylabel('f(z)')
plt.title(r'Graph of $f(z) = 2 + \sqrt{z^2 + 1}$')  # Fixed: Added 'r' for raw string
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.ylim(0, 10)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 4
# - Find the Domain and Range of $h(y) = -3\sqrt{14 + 3y}$
#
# ### Solution
#
# **Domain**
# 1. The expression under square root must satisfy:
#    $$14 + 3y \geq 0$$
# 2. Solve the inequality:
#    $$3y \geq -14$$
#    $$y \geq -\frac{14}{3}$$
# 3. Therefore, the domain is:
# $$
# \boxed{D = \left[-\frac{14}{3}, \infty\right)}
# $$
#
# **Range**
# 1. Analyze the components:
#    - $\sqrt{14 + 3y}$ has range $[0, \infty)$ since square roots are non-negative
#    - Multiplying by -3 reflects and scales the function: $-3\sqrt{14 + 3y}$ has range $(-\infty, 0]$
# 2. The maximum value occurs at the domain endpoint:
#    - When $y = -\frac{14}{3}$: $h(y) = -3\sqrt{0} = 0$
#    - As $y$ increases, $h(y)$ decreases without bound
# 3. Therefore the range is:
# $$
# \boxed{R = (-\infty, 0]}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def h(y):
    return -3 * np.sqrt(14 + 3 * y)

# Domain: y >= -14/3
y_min = -14 / 3
y_values = np.linspace(y_min, y_min + 10, 400)  # Start from domain minimum
h_values = h(y_values)

# Find the maximum (at y = y_min)
h_max = h(y_min)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(y_values, h_values, 
         label=r'$h(y) = -3\sqrt{14 + 3y}$', 
         color='purple', linewidth=2)

# Mark the maximum point
plt.scatter(y_min, h_max, color='red', 
            label=r'Max at $y = -\frac{14}{3}$', zorder=5)

# Domain and range annotations (using raw strings)
plt.axvline(y_min, color='gray', linestyle=':', 
            label=r'Domain: $y \geq -\frac{14}{3}$')
plt.axhline(0, color='green', linestyle='--', 
            label=r'Range: $h(y) \leq 0$')

# Labels and title
plt.xlabel('y', fontsize=12)
plt.ylabel('h(y)', fontsize=12)
plt.title(r'Graph of $h(y) = -3\sqrt{14 + 3y}$', pad=20)
plt.grid(True, linestyle='--', alpha=0.4)

# Adjust axes limits for better view
plt.xlim(y_min - 0.5, y_min + 10)
plt.ylim(h(y_min + 10) - 2, h_max + 2)

plt.legend(loc='upper right', bbox_to_anchor=(1, 0.95))
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 5
# - Find the Domain and Range of $M(x) = 5 - |x + 8|$
#
# ### Solution
#
# **Domain**
# 1. Absolute value functions are defined for all real numbers
# 2. Therefore, no restrictions on $x$:
# $$
# \boxed{D = (-\infty, \infty)}
# $$
#
# **Range**
# 1. Analyze the components:
#    - $|x + 8| \geq 0$ for all real $x$
#    - $-|x + 8| \leq 0$ (multiplying by -1 reverses inequality)
#    - $5 - |x + 8| \leq 5$ (adding 5 to both sides)
# 2. The maximum value occurs when $|x + 8| = 0$:
#    - At $x = -8$: $M(-8) = 5 - 0 = 5$
# 3. As $|x + 8|$ increases, $M(x)$ decreases without bound
# 4. Therefore the range is:
# $$
# \boxed{R = (-\infty, 5]}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function M(x)
def M(x):
    return 5 - np.abs(x + 8)

# Generate x values
x = np.linspace(-20, 4, 400)  # Adjust the range to include the vertex and show behavior

# Calculate y values
y = M(x)

# Plot the function
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='$M(x) = 5 - |x + 8|$', color='blue')

# Highlight the vertex (maximum point)
vertex_x = -8
vertex_y = M(vertex_x)
plt.scatter(vertex_x, vertex_y, color='red', label=f'Vertex at ({vertex_x}, {vertex_y})')

# Annotate the domain and range
plt.axhline(y=5, color='green', linestyle='--', label='Maximum Value (Range)')
plt.axhline(y=0, color='purple', linestyle='--', label='Reference Line')
plt.axvline(x=-20, color='orange', linestyle='--', label='Domain: All Real Numbers')
plt.axvline(x=4, color='orange', linestyle='--')

# Add labels and title
plt.xlabel('x (Domain: $(-\\infty, \\infty)$)')
plt.ylabel('M(x) (Range: $(-\\infty, 5]$)')
plt.title('Graph of $M(x) = 5 - |x + 8|$ with Domain and Range')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
